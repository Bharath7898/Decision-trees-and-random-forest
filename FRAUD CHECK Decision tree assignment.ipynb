# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets  
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\DELL\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# import some data to play with
df = pd.read_csv(r"C:\Users\DELL\Desktop\bharath's file\DS\csv\Fraud_check.csv")
df.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
label_encoder = preprocessing.LabelEncoder()
df["Undergrad"] = label_encoder.fit_transform(df["Undergrad"])
df["Marital.Status"] = label_encoder.fit_transform(df["Marital.Status"])
df["Urban"] = label_encoder.fit_transform(df["Urban"])

# %%
x=df.iloc[:,0:5]
y=df["Urban"]

# %%
x
# Out:
#      Undergrad  Marital.Status  Taxable.Income  City.Population  \
# 0            0               2           68833            50047
# 1            1               0           33700           134075
# 2            0               1           36925           160205
# 3            1               2           50190           193264
# 4            0               1           81002            27533
# ..         ...             ...             ...              ...
# 595          1               0           76340            39492
# 596          1               0           69967            55369
# 597          0               0           47334           154058
# 598          1               1           98592           180083
# 599          0               0           96519           158137
#
#      Work.Experience
# 0                 10
# 1                 18
# 2                 30
# 3                 15
# 4                 28
# ..               ...
# 595                7
# 596                2
# 597                0
# 598               17
# 599               16
#
# [600 rows x 5 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 595    1
# 596    1
# 597    1
# 598    0
# 599    0
# Name: Urban, Length: 600, dtype: int32

# %%
df.Urban.value_counts()
# Out:
# 1    302
# 0    298
# Name: Urban, dtype: int64

# %%
colnames=list(df.columns)

# %%
colnames
# Out:
# ['Undergrad',
#  'Marital.Status',
#  'Taxable.Income',
#  'City.Population',
#  'Work.Experience',
#  'Urban']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30)

# %%
model=DecisionTreeClassifier(criterion="gini")
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
#PLot the decision tree
fig, axes = plt.subplots(figsize = (10, 18), dpi=400)
tree.plot_tree(model)
# Out:
# [Text(1626.9134521484375, 5306.571428571428, 'X[2] <= 70117.0\ngini = 0.5\nsamples = 420\nvalue = [211, 209]'),
#  Text(674.530029296875, 5047.714285714286, 'X[2] <= 16199.0\ngini = 0.495\nsamples = 284\nvalue = [156, 128]'),
#  Text(72.65625, 4788.857142857143, 'X[2] <= 14410.0\ngini = 0.436\nsamples = 28\nvalue = [9, 19]'),
#  Text(48.4375, 4530.0, 'X[2] <= 10802.5\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(24.21875, 4271.142857142857, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(72.65625, 4271.142857142857, 'X[2] <= 10960.0\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(48.4375, 4012.2857142857147, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(96.875, 4012.2857142857147, 'X[3] <= 58447.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(72.65625, 3753.4285714285716, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(121.09375, 3753.4285714285716, 'X[3] <= 117599.0\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(96.875, 3494.5714285714284, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(145.3125, 3494.5714285714284, 'X[1] <= 0.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(121.09375, 3235.714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(169.53125, 3235.714285714286, 'X[3] <= 135007.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(145.3125, 2976.857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(193.75, 2976.857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(96.875, 4530.0, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(1276.40380859375, 4788.857142857143, 'X[1] <= 1.5\ngini = 0.489\nsamples = 256\nvalue = [147, 109]'),
#  Text(860.5224609375, 4530.0, 'X[3] <= 160674.0\ngini = 0.459\nsamples = 165\nvalue = [106, 59]'),
#  Text(461.669921875, 4271.142857142857, 'X[3] <= 38452.5\ngini = 0.482\nsamples = 133\nvalue = [79, 54]'),
#  Text(242.1875, 4012.2857142857147, 'X[1] <= 0.5\ngini = 0.231\nsamples = 15\nvalue = [13, 2]'),
#  Text
 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2821.484375, 4788.857142857143, 'X[4] <= 20.0\ngini = 0.5\nsamples = 75\nvalue = [38, 37]'),
#  Text(2712.5, 4530.0, 'X[3] <= 162558.0\ngini = 0.483\nsamples = 49\nvalue = [20, 29]'),
#  Text(2615.625, 4271.142857142857, 'X[4] <= 8.5\ngini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(2542.96875, 4012.2857142857147, 'X[0] <= 0.5\ngini = 0.444\nsamples = 18\nvalue = [6, 12]'),
#  Text(2518.75, 3753.4285714285716, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(2567.1875, 3753.4285714285716, 'X[3] <= 100499.0\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(2542.96875, 3494.5714285714284, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2591.40625, 3494.5714285714284, 'X[3] <= 115109.5\ngini = 0.496\nsamples = 11\nvalue = [6, 5]'),
#  Text(2567.1875, 3235.714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2615.625, 3235.714285714286, 'X[3] <= 133307.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(2591.40625, 2976.857142857143, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2639.84375, 2976.857142857143, 'X[1] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(2615.625, 2718.0000000000005, 'X[3] <= 147394.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(2591.40625, 2459.1428571428573, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2639.84375, 2459.1428571428573, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2664.0625, 2718.0000000000005, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2688.28125, 4012.2857142857147, 'X[0] <= 0.5\ngini = 0.355\nsamples = 13\nvalue = [10, 3]'),
#  Text(2664.0625, 3753.4285714285716, 'X[2] <= 82068.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(2639.84375, 3494.5714285714284, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2688.28125, 3494.5714285714284, 'X[2] <= 94101.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(2664.0625, 3235.714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2712.5, 3235.714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2712.5, 3753.4285714285716, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(2809.375, 4271.142857142857, 'X[3] <= 195618.5\ngini = 0.346\nsamples = 18\nvalue = [4, 14]'),
#  Text(2785.15625, 4012.2857142857147, 'X[2] <= 86305.0\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(2760.9375, 3753.4285714285716, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(2809.375, 3753.4285714285716, 'X[2] <= 91957.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(2785.15625, 3494.5714285714284, 'X[3] <= 168256.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(2760.9375, 3235.714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2809.375, 3235.714285714286, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2833.59375, 3494.5714285714284, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2833.59375, 4012.2857142857147, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2930.46875, 4530.0, 'X[4] <= 23.5\ngini = 0.426\nsamples = 26\nvalue = [18, 8]'),
#  Text(2906.25, 4271.142857142857, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(2954.6875, 4271.142857142857, 'X[3] <= 108220.0\ngini = 0.48\nsamples = 20\nvalue = [12, 8]'),
#  Text(2930.46875, 4012.2857142857147, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2978.90625, 4012.2857142857147, 'X[2] <= 93238.0\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(2906.25, 3753.4285714285716, 'X[1] <= 1.5\ngini = 0.278\nsamples = 12\nvalue = [10, 2]'),
#  Text(2882.03125, 3494.5714285714284, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(2930.46875, 3494.5714285714284, 'X[2] <= 81126.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(2906.25, 3235.714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2954.6875, 3235.714285714286, 'X[0] <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(2930.46875, 2976.857142857143, 'X[4] <= 25.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(2906.25, 2718.0000000000005, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2954.6875, 2718.0000000000005, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2978.90625, 2976.857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3051.5625, 3753.4285714285716, 'X[0] <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(3027.34375, 3494.5714285714284, 'X[2] <= 96235.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(3003.125, 3235.714285714286, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3051.5625, 3235.714285714286, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3075.78125, 3494.5714285714284, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]')]

# %%
fn=[ 'Undergrad',
 'Marital.Status',
 'Taxable.Income',
 'City.Population',
 'Work.Experience']
cn=['Not Urban','Urban']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (10,8), dpi=600)
tree.plot_tree(model,feature_names = fn, class_names=cn,filled = True);

# %%
preds=model.predict(x_test)
pd.Series(preds).value_counts()
# Out:
# 1    98
# 0    82
# dtype: int64

# %%
pd.Series(y_test).value_counts()
# Out:
# 1    93
# 0    87
# Name: Urban, dtype: int64

# %%
pd.crosstab(y_test,preds)
# Out:
# col_0   0   1
# Urban
# 0      41  46
# 1      41  52

# %%
np.mean(preds==y_test)
# Out:
# 0.5166666666666667

# %%
array=df.values

# %%
X=array[:,0:5]
Y=array[:,5]

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.26)

# %%
from sklearn.tree import DecisionTreeRegressor
model1=DecisionTreeRegressor()

# %%
model1.fit(X_train, Y_train)
# Out:
# DecisionTreeRegressor()

# %%
model1.score(X_test, Y_test)
# Out:
# -0.7931034482758625
